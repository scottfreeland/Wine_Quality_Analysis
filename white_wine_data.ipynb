# %% [markdown]
# <a href="https://colab.research.google.com/github/scottfreeland/Wine_Quality_Analysis/blob/rich/white_wine_data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Import our dependencies
# %matplotlib inline
import pandas as pd
from pathlib import Path
import numpy as np
import matplotlib.pyplot as plt
import plotly.express as px
import os

#  Import and read the wine_quality_master.csv.
urlr = 'https://raw.githubusercontent.com/scottfreeland/Wine_Quality_Analysis/main/red_wine_quality.csv'
urlw = 'https://raw.githubusercontent.com/scottfreeland/Wine_Quality_Analysis/main/white_wine_quality.csv'

# %%
df_red_wine= pd.read_csv(urlr)
df_red_wine.head()
# Out:
#   type  fixed_acidity  volatile_acidity  ...  sulfates  alcohol  quality
# 0  red            7.4              0.70  ...      0.56      9.4        5
# 1  red            7.8              0.88  ...      0.68      9.8        5
# 2  red            7.8              0.76  ...      0.65      9.8        5
# 3  red           11.2              0.28  ...      0.58      9.8        6
# 4  red            7.4              0.70  ...      0.56      9.4        5
#
# [5 rows x 13 columns]

# %%
df_white_wine= pd.read_csv(urlw)
df_white_wine.head()
# Out:
#     type  fixed_acidity  volatile_acidity  ...  sulfates  alcohol  quality
# 0  white            7.0              0.27  ...      0.45      8.8        6
# 1  white            6.3              0.30  ...      0.49      9.5        6
# 2  white            8.1              0.28  ...      0.44     10.1        6
# 3  white            7.2              0.23  ...      0.40      9.9        6
# 4  white            7.2              0.23  ...      0.40      9.9        6
#
# [5 rows x 13 columns]

# %%
df_red_wine.describe()
# Out:
#        fixed_acidity  volatile_acidity  ...      alcohol      quality
# count    1593.000000       1593.000000  ...  1593.000000  1593.000000
# mean        8.326365          0.527659  ...    10.419617     5.636535
# std         1.740681          0.179297  ...     1.065206     0.807687
# min         4.600000          0.120000  ...     8.400000     3.000000
# 25%         7.100000          0.390000  ...     9.500000     5.000000
# 50%         7.900000          0.520000  ...    10.200000     6.000000
# 75%         9.200000          0.640000  ...    11.100000     6.000000
# max        15.900000          1.580000  ...    14.900000     8.000000
#
# [8 rows x 12 columns]

# %%
df_white_wine.describe()
# Out:
#        fixed_acidity  volatile_acidity  ...      alcohol      quality
# count    4870.000000       4870.000000  ...  4870.000000  4870.000000
# mean        6.855123          0.278071  ...    10.516772     5.878029
# std         0.843444          0.100528  ...     1.231251     0.885699
# min         3.800000          0.080000  ...     8.000000     3.000000
# 25%         6.300000          0.210000  ...     9.500000     5.000000
# 50%         6.800000          0.260000  ...    10.400000     6.000000
# 75%         7.300000          0.320000  ...    11.400000     6.000000
# max        14.200000          1.100000  ...    14.200000     9.000000
#
# [8 rows x 12 columns]

# %%
# Missing Values
print(df_white_wine.isna().sum())

print(df_red_wine.isna().sum())
# Out:
# type                    0
# fixed_acidity           0
# volatile_acidity        0
# citric_acid             0
# residual_sugar          0
# chlorides               0
# free_sulfur_dioxide     0
# total_sulfur_dioxide    0
# density                 0
# ph                      0
# sulfates                0
# alcohol                 0
# quality                 0
# dtype: int64
# type                    0
# fixed_acidity           0
# volatile_acidity        0
# citric_acid             0
# residual_sugar          0
# chlorides               0
# free_sulfur_dioxide     0
# total_sulfur_dioxide    0
# density                 0
# ph                      0
# sulfates                0
# alcohol                 0
# quality                 0
# dtype: int64

# %%
# Assign the data to X and y
# Note: Sklearn requires a two-dimensional array of values
# so we use reshape() to create this

#X = df_red_wine[['fixed_acidity','volatile_acidity','citric_acid','residual_sugar','chlorides','free_sulfur_dioxide','total_sulfur_dioxide','density','ph','sulfates','alcohol']]
#y = df_red_wine['quality']

print("Shape: ", X.shape, y.shape)
# Out:
# Shape:  (1593, 11) (1593,)

# %%
# prepping 
from sklearn.preprocessing import StandardScaler
X_features = X
X = StandardScaler().fit_transform(X)

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=1)

# %%
from sklearn.linear_model import LogisticRegression
classifier = LogisticRegression()
classifier
# Out:
# LogisticRegression()

# %%
classifier.fit(X_train, y_train)
# Out:
# LogisticRegression()

# %%
print(f"Training Data Score: {classifier.score(X_train, y_train)}")
print(f"Testing Data Score: {classifier.score(X_test, y_test)}")
# Out:
# Training Data Score: 0.6122278056951423
# Testing Data Score: 0.5989974937343359

# %%
#Make predictions
print(f'Actual:\t\t{list(y_test[:10])}')
print(f'Predicted:\t{list(classifier.predict(X_test[:10]))}')
# Out:
# Actual:		[5, 5, 5, 5, 7, 6, 7, 5, 5, 5]
# Predicted:	[5, 5, 5, 6, 7, 5, 6, 5, 5, 5]

# %%
#X = df_red_wine.values.reshape(-1, 1)

# %%
plt.scatter(df_red_wine['quality'], df_red_wine['alcohol'])
plt.xlabel('quality')
plt.ylabel('alcohol')
plt.show()

# %%
y = df_red_wine["quality"]
X = df_red_wine.drop(columns=["quality","type"])
# df.drop(columns =['C', 'D'])

# %%
#from sklearn import preprocessing
#X = preprocessing.StandardScaler().fit(X).transform(X)

# %%
from sklearn.preprocessing import StandardScaler
data_scaler = StandardScaler()

# %%
red_wine_quality = data_scaler.fit_transform(df_red_wine.drop(columns = 'type'))

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X,
   y,  random_state=1, stratify=y)
X_train.shape
# Out:
# (1194, 11)

# %%
from sklearn.svm import SVC
model = SVC(kernel='linear')
#SVM is one model that usually benefits from scaling.

# %%
model.fit(X_train, y_train)
# Out:
# SVC(kernel='linear')

# %%
y_pred = model.predict(X_test)
results = pd.DataFrame({
   "Prediction": y_pred,
   "Actual": y_test
}).reset_index(drop=True)
results.head()
# Out:
#    Prediction  Actual
# 0           6       6
# 1           6       7
# 2           6       6
# 3           5       3
# 4           6       4

# %%
from sklearn.metrics import accuracy_score
accuracy_score(y_test, y_pred)
# Out:
# 0.5764411027568922

# %%
from sklearn.metrics import confusion_matrix
confusion_matrix(y_test, y_pred)

from sklearn.metrics import classification_report
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            3       0.00      0.00      0.00         2
#            4       0.00      0.00      0.00        13
#            5       0.65      0.75      0.70       170
#            6       0.50      0.65      0.57       159
#            7       0.00      0.00      0.00        50
#            8       0.00      0.00      0.00         5
#
#     accuracy                           0.58       399
#    macro avg       0.19      0.23      0.21       399
# weighted avg       0.48      0.58      0.52       399
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# ...
