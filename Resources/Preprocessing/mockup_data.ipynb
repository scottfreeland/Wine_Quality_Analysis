# %% [markdown]
# <a href="https://colab.research.google.com/github/scottfreeland/Wine_Quality_Analysis/blob/rich/mockup_data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Import our dependencies
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt


#  Import and read the wine_quality_master.csv.
url = 'https://raw.githubusercontent.com/scottfreeland/Wine_Quality_Analysis/main/winequalitymaster.csv'
df_wine= pd.read_csv(url)
df_wine.head()
# Out:
#     type  fixed acidity  volatile acidity  ...  sulphates  alcohol  quality
# 0  white            7.0              0.27  ...       0.45      8.8        6
# 1  white            6.3              0.30  ...       0.49      9.5        6
# 2  white            8.1              0.28  ...       0.44     10.1        6
# 3  white            7.2              0.23  ...       0.40      9.9        6
# 4  white            7.2              0.23  ...       0.40      9.9        6
#
# [5 rows x 13 columns]

# %%
df_wine.dropna()
# Out:
#        type  fixed acidity  volatile acidity  ...  sulphates  alcohol  quality
# 0     white            7.0             0.270  ...       0.45      8.8        6
# 1     white            6.3             0.300  ...       0.49      9.5        6
# 2     white            8.1             0.280  ...       0.44     10.1        6
# 3     white            7.2             0.230  ...       0.40      9.9        6
# 4     white            7.2             0.230  ...       0.40      9.9        6
# ...     ...            ...               ...  ...        ...      ...      ...
# 6491    red            6.8             0.620  ...       0.82      9.5        6
# 6492    red            6.2             0.600  ...       0.58     10.5        5
# 6494    red            6.3             0.510  ...       0.75     11.0        6
# 6495    red            5.9             0.645  ...       0.71     10.2        5
# 6496    red            6.0             0.310  ...       0.66     11.0        6
#
# ...

# %%
df_wine.describe()
# Out:
#        fixed acidity  volatile acidity  ...      alcohol      quality
# count    6487.000000       6489.000000  ...  6497.000000  6497.000000
# mean        7.216579          0.339691  ...    10.491801     5.818378
# std         1.296750          0.164649  ...     1.192712     0.873255
# min         3.800000          0.080000  ...     8.000000     3.000000
# 25%         6.400000          0.230000  ...     9.500000     5.000000
# 50%         7.000000          0.290000  ...    10.300000     6.000000
# 75%         7.700000          0.400000  ...    11.300000     6.000000
# max        15.900000          1.580000  ...    14.900000     9.000000
#
# [8 rows x 12 columns]

# %%
# Mock Machine Learning Model
import pandas as pd
from pathlib import Path
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

# %%
# Missing Values
print(df_wine.isna().sum())
# Out:
# type                     0
# fixed acidity           10
# volatile acidity         8
# citric acid              3
# residual sugar           2
# chlorides                2
# free sulfur dioxide      0
# total sulfur dioxide     0
# density                  0
# pH                       9
# sulphates                4
# alcohol                  0
# quality                  0
# dtype: int64

# %%
df_wine.dropna()
# Out:
#        type  fixed acidity  volatile acidity  ...  sulphates  alcohol  quality
# 0     white            7.0             0.270  ...       0.45      8.8        6
# 1     white            6.3             0.300  ...       0.49      9.5        6
# 2     white            8.1             0.280  ...       0.44     10.1        6
# 3     white            7.2             0.230  ...       0.40      9.9        6
# 4     white            7.2             0.230  ...       0.40      9.9        6
# ...     ...            ...               ...  ...        ...      ...      ...
# 6491    red            6.8             0.620  ...       0.82      9.5        6
# 6492    red            6.2             0.600  ...       0.58     10.5        5
# 6494    red            6.3             0.510  ...       0.75     11.0        6
# 6495    red            5.9             0.645  ...       0.71     10.2        5
# 6496    red            6.0             0.310  ...       0.66     11.0        6
#
# ...
