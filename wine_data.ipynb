# %%
# importing pandas as pd
import pandas as pd

# %%
# Creating the dataframe 
df_wine = pd.read_csv("winequalityN.csv")

# %%
df_wine
# Out:
#        type  fixed acidity  volatile acidity  citric acid  residual sugar  \
# 0     white            7.0             0.270         0.36            20.7
# 1     white            6.3             0.300         0.34             1.6
# 2     white            8.1             0.280         0.40             6.9
# 3     white            7.2             0.230         0.32             8.5
# 4     white            7.2             0.230         0.32             8.5
# ...     ...            ...               ...          ...             ...
# 6492    red            6.2             0.600         0.08             2.0
# 6493    red            5.9             0.550         0.10             2.2
# 6494    red            6.3             0.510         0.13             2.3
# 6495    red            5.9             0.645         0.12             2.0
# 6496    red            6.0             0.310         0.47             3.6
#
#       chlorides  free sulfur dioxide  total sulfur dioxide  density    pH  \
# ...

# %%
df_wine.dtypes
# Out:
# type                     object
# fixed acidity           float64
# volatile acidity        float64
# citric acid             float64
# residual sugar          float64
# chlorides               float64
# free sulfur dioxide     float64
# total sulfur dioxide    float64
# density                 float64
# pH                      float64
# sulphates               float64
# alcohol                 float64
# quality                   int64
# dtype: object

# %%
df_wine.dropna()
# Out:
#        type  fixed acidity  volatile acidity  citric acid  residual sugar  \
# 0     white            7.0             0.270         0.36            20.7
# 1     white            6.3             0.300         0.34             1.6
# 2     white            8.1             0.280         0.40             6.9
# 3     white            7.2             0.230         0.32             8.5
# 4     white            7.2             0.230         0.32             8.5
# ...     ...            ...               ...          ...             ...
# 6491    red            6.8             0.620         0.08             1.9
# 6492    red            6.2             0.600         0.08             2.0
# 6494    red            6.3             0.510         0.13             2.3
# 6495    red            5.9             0.645         0.12             2.0
# 6496    red            6.0             0.310         0.47             3.6
#
#       chlorides  free sulfur dioxide  total sulfur dioxide  density    pH  \
# ...

# %%
df_wine.to_csv('wine_cleaned.csv')

# %%
# To find the correlation among
# the columns using pearson method
df_wine.corr(method ='pearson')
# Out:
#                       fixed acidity  volatile acidity  citric acid  \
# fixed acidity              1.000000          0.220172     0.323736
# volatile acidity           0.220172          1.000000    -0.378061
# citric acid                0.323736         -0.378061     1.000000
# residual sugar            -0.112319         -0.196702     0.142486
# chlorides                  0.298421          0.377167     0.039315
# free sulfur dioxide       -0.283317         -0.353230     0.133437
# total sulfur dioxide      -0.329747         -0.414928     0.195218
# density                    0.459204          0.271193     0.096320
# pH                        -0.251814          0.260660    -0.328689
# sulphates                  0.300380          0.225476     0.057613
# alcohol                   -0.095603         -0.038248    -0.010433
# quality                   -0.077031         -0.265953     0.085706
#
#                       residual sugar  chlorides  free sulfur dioxide  \
# ...

# %%
df_white_wine = pd.read_csv("white_wine_quality.csv")
df_white_wine
# Out:
#        type  fixed_acidity  volatile_acidity  citric_acid  residual_sugar  \
# 0     white            7.0              0.27         0.36            20.7
# 1     white            6.3              0.30         0.34             1.6
# 2     white            8.1              0.28         0.40             6.9
# 3     white            7.2              0.23         0.32             8.5
# 4     white            7.2              0.23         0.32             8.5
# ...     ...            ...               ...          ...             ...
# 4865  white            5.7              0.21         0.32             0.9
# 4866  white            6.2              0.21         0.29             1.6
# 4867  white            6.6              0.32         0.36             8.0
# 4868  white            5.5              0.29         0.30             1.1
# 4869  white            6.0              0.21         0.38             0.8
#
#       chlorides  free_sulfur_dioxide  total_sulfur_dioxide  density    ph  \
# ...

# %%
df_red_wine = pd.read_csv("red_wine_quality.csv")
df_red_wine
# Out:
#      type  fixed_acidity  volatile_acidity  citric_acid  residual_sugar  \
# 0     red            7.4             0.700         0.00             1.9
# 1     red            7.8             0.880         0.00             2.6
# 2     red            7.8             0.760         0.04             2.3
# 3     red           11.2             0.280         0.56             1.9
# 4     red            7.4             0.700         0.00             1.9
# ...   ...            ...               ...          ...             ...
# 1588  red            6.8             0.620         0.08             1.9
# 1589  red            6.2             0.600         0.08             2.0
# 1590  red            6.3             0.510         0.13             2.3
# 1591  red            5.9             0.645         0.12             2.0
# 1592  red            6.0             0.310         0.47             3.6
#
#       chlorides  free_sulfur_dioxide  total_sulfur_dioxide  density    ph  \
# ...

# %%
# To find the correlation among
# the columns using pearson method
df_white_wine.corr(method ='pearson')
# Out:
#                       fixed_acidity  volatile_acidity  citric_acid  \
# fixed_acidity              1.000000         -0.020301     0.287439
# volatile_acidity          -0.020301          1.000000    -0.148473
# citric_acid                0.287439         -0.148473     1.000000
# residual_sugar             0.087979          0.064111     0.094602
# chlorides                  0.023588          0.072686     0.113034
# free_sulfur_dioxide       -0.049226         -0.096982     0.093018
# total_sulfur_dioxide       0.091347          0.089975     0.122023
# density                    0.265525          0.027326     0.150368
# ph                        -0.424343         -0.034612    -0.161527
# sulfates                  -0.016492         -0.034965     0.064418
# alcohol                   -0.121851          0.067772    -0.076580
# quality                   -0.112172         -0.196657    -0.010079
#
#                       residual_sugar  chlorides  free_sulfur_dioxide  \
# ...

# %%
# To find the correlation among
# the columns using pearson method
df_red_wine.corr(method ='pearson')
# Out:
#                       fixed_acidity  volatile_acidity  citric_acid  \
# fixed_acidity              1.000000         -0.255880     0.671009
# volatile_acidity          -0.255880          1.000000    -0.553469
# citric_acid                0.671009         -0.553469     1.000000
# residual_sugar             0.115362          0.001768     0.143996
# chlorides                  0.093307          0.061519     0.203932
# free_sulfur_dioxide       -0.151817         -0.011658    -0.059141
# total_sulfur_dioxide      -0.113958          0.075897     0.034533
# density                    0.667893          0.022572     0.364505
# ph                        -0.681961          0.234674    -0.540704
# sulfates                   0.185017         -0.261678     0.314786
# alcohol                   -0.059236         -0.203623     0.111810
# quality                    0.123564         -0.391075     0.226345
#
#                       residual_sugar  chlorides  free_sulfur_dioxide  \
# ...
