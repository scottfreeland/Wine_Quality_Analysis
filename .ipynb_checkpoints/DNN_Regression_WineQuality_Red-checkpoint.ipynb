# %%
# Import our dependencies
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler,OneHotEncoder
import pandas as pd
import tensorflow as tf

#  Import and read the red_wine_quality.csv.
import pandas as pd 
red_wine_df = pd.read_csv("red_wine_quality.csv")
red_wine_df
# Out:
#      type  fixed_acidity  volatile_acidity  citric_acid  residual_sugar  \
# 0     red            7.4             0.700         0.00             1.9
# 1     red            7.8             0.880         0.00             2.6
# 2     red            7.8             0.760         0.04             2.3
# 3     red           11.2             0.280         0.56             1.9
# 4     red            7.4             0.700         0.00             1.9
# ...   ...            ...               ...          ...             ...
# 1588  red            6.8             0.620         0.08             1.9
# 1589  red            6.2             0.600         0.08             2.0
# 1590  red            6.3             0.510         0.13             2.3
# 1591  red            5.9             0.645         0.12             2.0
# 1592  red            6.0             0.310         0.47             3.6
#
#       chlorides  free_sulfur_dioxide  total_sulfur_dioxide  density    ph  \
# ...

# %%
# Drop the non-beneficial ID columns, 'residual_sugar', 'free_sulfur_dioxide', and 'ph'.
red_wine_df.drop(['residual_sugar', 'free_sulfur_dioxide', 'ph'], axis=1, inplace=True)

# %%
# Determine the number of unique values in each column of red_wine_df.
red_wine_df.nunique()
# Out:
# type                      1
# fixed_acidity            96
# volatile_acidity        143
# citric_acid              80
# chlorides               153
# total_sulfur_dioxide    144
# density                 435
# sulfates                 96
# alcohol                  65
# quality                   6
# dtype: int64

# %%
# Look at fixed_acidity value counts for binning
fixed_acidity_value_counts = red_wine_df['fixed_acidity'].value_counts()
fixed_acidity_value_counts
# Out:
# 7.2     66
# 7.1     57
# 7.8     53
# 7.5     52
# 7.0     49
#         ..
# 13.5     1
# 13.8     1
# 13.4     1
# 4.7      1
# 5.5      1
# Name: fixed_acidity, Length: 96, dtype: int64

# %%
# Visualize the value counts of fixed_acidity
fixed_acidity_value_counts.plot.density()
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()

red_wine_df[['fixed_acidity']] = scaler.fit_transform(red_wine_df[['fixed_acidity']])

red_wine_df
# Out:
#      type  fixed_acidity  volatile_acidity  citric_acid  chlorides  \
# 0     red      -0.532353             0.700         0.00      0.076
# 1     red      -0.302485             0.880         0.00      0.098
# 2     red      -0.302485             0.760         0.04      0.092
# 3     red       1.651386             0.280         0.56      0.075
# 4     red      -0.532353             0.700         0.00      0.076
# ...   ...            ...               ...          ...        ...
# 1588  red      -0.877154             0.620         0.08      0.068
# 1589  red      -1.221955             0.600         0.08      0.090
# 1590  red      -1.164488             0.510         0.13      0.076
# 1591  red      -1.394355             0.645         0.12      0.075
# 1592  red      -1.336888             0.310         0.47      0.067
#
#       total_sulfur_dioxide  density  sulfates  alcohol  quality
# 0                     34.0  0.99780      0.56      9.4        5
# ...

# %%
fixed_acidity_value_counts = red_wine_df['fixed_acidity'].value_counts()
fixed_acidity_value_counts
# Out:
# -0.647286    66
# -0.704753    57
# -0.302485    53
# -0.474886    52
# -0.762220    49
#              ..
#  2.973123     1
#  3.145524     1
#  2.915657     1
# -2.083957     1
# -1.624222     1
# Name: fixed_acidity, Length: 96, dtype: int64

# %%
red_wine_df['fixed_acidity'] = red_wine_df['fixed_acidity'].round(decimals = 0)
red_wine_df
# Out:
#      type  fixed_acidity  volatile_acidity  citric_acid  chlorides  \
# 0     red           -1.0             0.700         0.00      0.076
# 1     red           -0.0             0.880         0.00      0.098
# 2     red           -0.0             0.760         0.04      0.092
# 3     red            2.0             0.280         0.56      0.075
# 4     red           -1.0             0.700         0.00      0.076
# ...   ...            ...               ...          ...        ...
# 1588  red           -1.0             0.620         0.08      0.068
# 1589  red           -1.0             0.600         0.08      0.090
# 1590  red           -1.0             0.510         0.13      0.076
# 1591  red           -1.0             0.645         0.12      0.075
# 1592  red           -1.0             0.310         0.47      0.067
#
#       total_sulfur_dioxide  density  sulfates  alcohol  quality
# 0                     34.0  0.99780      0.56      9.4        5
# ...

# %%
# Determine the number of unique values in each column of red_wine_df.
red_wine_df.nunique()
# Out:
# type                      1
# fixed_acidity             7
# volatile_acidity        143
# citric_acid              80
# chlorides               153
# total_sulfur_dioxide    144
# density                 435
# sulfates                 96
# alcohol                  65
# quality                   6
# dtype: int64

# %%
# Look at volatile_acidity value counts for binning
volatile_acidity_value_counts = red_wine_df['volatile_acidity'].value_counts()
volatile_acidity_value_counts
# Out:
# 0.600    47
# 0.500    46
# 0.430    43
# 0.590    39
# 0.580    38
#          ..
# 1.035     1
# 0.565     1
# 1.130     1
# 1.115     1
# 1.090     1
# Name: volatile_acidity, Length: 143, dtype: int64

# %%
# Visualize the value counts of volatile_acidity
volatile_acidity_value_counts.plot.density()
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
scaler = StandardScaler()

red_wine_df[['volatile_acidity']] = scaler.fit_transform(red_wine_df[['volatile_acidity']])

red_wine_df
# Out:
#      type  fixed_acidity  volatile_acidity  citric_acid  chlorides  \
# 0     red           -1.0          0.961511         0.00      0.076
# 1     red           -0.0          1.965750         0.00      0.098
# 2     red           -0.0          1.296257         0.04      0.092
# 3     red            2.0         -1.381713         0.56      0.075
# 4     red           -1.0          0.961511         0.00      0.076
# ...   ...            ...               ...          ...        ...
# 1588  red           -1.0          0.515183         0.08      0.068
# 1589  red           -1.0          0.403601         0.08      0.090
# 1590  red           -1.0         -0.098519         0.13      0.076
# 1591  red           -1.0          0.654660         0.12      0.075
# 1592  red           -1.0         -1.214339         0.47      0.067
#
#       total_sulfur_dioxide  density  sulfates  alcohol  quality
# 0                     34.0  0.99780      0.56      9.4        5
# ...

# %%
volatile_acidity_value_counts = red_wine_df['volatile_acidity'].value_counts()
volatile_acidity_value_counts
# Out:
#  0.403601    47
# -0.154310    46
# -0.544847    43
#  0.347810    39
#  0.292019    38
#              ..
#  2.830511     1
#  0.208332     1
#  3.360526     1
#  3.276839     1
#  3.137362     1
# Name: volatile_acidity, Length: 143, dtype: int64

# %%
red_wine_df['volatile_acidity'] = red_wine_df['volatile_acidity'].round(decimals = 0)
red_wine_df
# Out:
#      type  fixed_acidity  volatile_acidity  citric_acid  chlorides  \
# 0     red           -1.0               1.0         0.00      0.076
# 1     red           -0.0               2.0         0.00      0.098
# 2     red           -0.0               1.0         0.04      0.092
# 3     red            2.0              -1.0         0.56      0.075
# 4     red           -1.0               1.0         0.00      0.076
# ...   ...            ...               ...          ...        ...
# 1588  red           -1.0               1.0         0.08      0.068
# 1589  red           -1.0               0.0         0.08      0.090
# 1590  red           -1.0              -0.0         0.13      0.076
# 1591  red           -1.0               1.0         0.12      0.075
# 1592  red           -1.0              -1.0         0.47      0.067
#
#       total_sulfur_dioxide  density  sulfates  alcohol  quality
# 0                     34.0  0.99780      0.56      9.4        5
# ...

# %%
red_wine_df.nunique()
# Out:
# type                      1
# fixed_acidity             7
# volatile_acidity          8
# citric_acid              80
# chlorides               153
# total_sulfur_dioxide    144
# density                 435
# sulfates                 96
# alcohol                  65
# quality                   6
# dtype: int64

# %%
# Look at citric_acid value counts for binning
citric_acid_value_counts = red_wine_df['citric_acid'].value_counts()
citric_acid_value_counts
# Out:
# 0.00    131
# 0.49     68
# 0.24     51
# 0.02     50
# 0.26     38
#        ...
# 0.72      1
# 0.62      1
# 0.75      1
# 1.00      1
# 0.78      1
# Name: citric_acid, Length: 80, dtype: int64

# %%
red_wine_df['citric_acid'] = red_wine_df['citric_acid'].round(decimals = 1)
red_wine_df
# Out:
#      type  fixed_acidity  volatile_acidity  citric_acid  chlorides  \
# 0     red           -1.0               1.0          0.0      0.076
# 1     red           -0.0               2.0          0.0      0.098
# 2     red           -0.0               1.0          0.0      0.092
# 3     red            2.0              -1.0          0.6      0.075
# 4     red           -1.0               1.0          0.0      0.076
# ...   ...            ...               ...          ...        ...
# 1588  red           -1.0               1.0          0.1      0.068
# 1589  red           -1.0               0.0          0.1      0.090
# 1590  red           -1.0              -0.0          0.1      0.076
# 1591  red           -1.0               1.0          0.1      0.075
# 1592  red           -1.0              -1.0          0.5      0.067
#
#       total_sulfur_dioxide  density  sulfates  alcohol  quality
# 0                     34.0  0.99780      0.56      9.4        5
# ...

# %%
red_wine_df.nunique()
# Out:
# type                      1
# fixed_acidity             7
# volatile_acidity          8
# citric_acid              10
# chlorides               153
# total_sulfur_dioxide    144
# density                 435
# sulfates                 96
# alcohol                  65
# quality                   6
# dtype: int64

# %%
# Look at chlorides value counts for binning
chlorides_value_counts = red_wine_df['chlorides'].value_counts()
chlorides_value_counts
# Out:
# -0.0     1231
# -1.0      218
#  1.0       81
#  2.0       22
#  3.0       14
#  7.0        9
#  6.0        5
#  5.0        4
#  4.0        3
#  8.0        2
#  11.0       2
# -2.0        2
# Name: chlorides, dtype: int64

# %%
scaler = StandardScaler()

red_wine_df[['chlorides']] = scaler.fit_transform(red_wine_df[['chlorides']])

red_wine_df
# Out:
#      type  fixed_acidity  volatile_acidity  citric_acid  chlorides  \
# 0     red           -1.0               1.0          0.0  -0.244002
# 1     red           -0.0               2.0          0.0   0.222900
# 2     red           -0.0               1.0          0.0   0.095563
# 3     red            2.0              -1.0          0.6  -0.265225
# 4     red           -1.0               1.0          0.0  -0.244002
# ...   ...            ...               ...          ...        ...
# 1588  red           -1.0               1.0          0.1  -0.413785
# 1589  red           -1.0               0.0          0.1   0.053117
# 1590  red           -1.0              -0.0          0.1  -0.244002
# 1591  red           -1.0               1.0          0.1  -0.265225
# 1592  red           -1.0              -1.0          0.5  -0.435008
#
#       total_sulfur_dioxide  density  sulfates  alcohol  quality
# 0                     34.0  0.99780      0.56      9.4        5
# ...

# %%
red_wine_df['chlorides'] = red_wine_df['chlorides'].round(decimals = 0)

# %%
red_wine_df.nunique()
# Out:
# type                      1
# fixed_acidity             7
# volatile_acidity          8
# citric_acid              10
# chlorides                12
# total_sulfur_dioxide    144
# density                 435
# sulfates                 96
# alcohol                  65
# quality                   6
# dtype: int64

# %%
# Look at total_sulfur_dioxide value counts for binning
total_sulfur_dioxide_value_counts = red_wine_df['total_sulfur_dioxide'].value_counts()
total_sulfur_dioxide_value_counts
# Out:
# 28.0     42
# 24.0     36
# 15.0     35
# 23.0     34
# 18.0     34
#          ..
# 139.0     1
# 149.0     1
# 152.0     1
# 155.0     1
# 165.0     1
# Name: total_sulfur_dioxide, Length: 144, dtype: int64

# %%
scaler = StandardScaler()

red_wine_df[['total_sulfur_dioxide']] = scaler.fit_transform(red_wine_df[['total_sulfur_dioxide']])

red_wine_df
# Out:
#      type  fixed_acidity  volatile_acidity  citric_acid  chlorides  \
# 0     red           -1.0               1.0          0.0       -0.0
# 1     red           -0.0               2.0          0.0        0.0
# 2     red           -0.0               1.0          0.0        0.0
# 3     red            2.0              -1.0          0.6       -0.0
# 4     red           -1.0               1.0          0.0       -0.0
# ...   ...            ...               ...          ...        ...
# 1588  red           -1.0               1.0          0.1       -0.0
# 1589  red           -1.0               0.0          0.1        0.0
# 1590  red           -1.0              -0.0          0.1       -0.0
# 1591  red           -1.0               1.0          0.1       -0.0
# 1592  red           -1.0              -1.0          0.5       -0.0
#
#       total_sulfur_dioxide  density  sulfates  alcohol  quality
# 0                -0.378803  0.99780      0.56      9.4        5
# ...

# %%
red_wine_df['total_sulfur_dioxide'] = red_wine_df['total_sulfur_dioxide'].round(decimals = 0)

# %%
red_wine_df.nunique()
# Out:
# type                      1
# fixed_acidity             7
# volatile_acidity          8
# citric_acid              10
# chlorides                12
# total_sulfur_dioxide      7
# density                 435
# sulfates                 96
# alcohol                  65
# quality                   6
# dtype: int64

# %%
# Look at density value counts for binning
density_value_counts = red_wine_df['density'].value_counts()
density_value_counts
# Out:
# 0.99720    36
# 0.99760    35
# 0.99680    34
# 0.99800    29
# 0.99620    28
#            ..
# 0.99617     1
# 0.99529     1
# 0.99451     1
# 0.99479     1
# 0.99651     1
# Name: density, Length: 435, dtype: int64

# %%
scaler = StandardScaler()

red_wine_df[['density']] = scaler.fit_transform(red_wine_df[['density']])

# %%
red_wine_df['density'] = red_wine_df['density'].round(decimals = 0)

# %%
red_wine_df.nunique()
# Out:
# type                     1
# fixed_acidity            7
# volatile_acidity         8
# citric_acid             10
# chlorides               12
# total_sulfur_dioxide     7
# density                  9
# sulfates                96
# alcohol                 65
# quality                  6
# dtype: int64

# %%
# Look at sulfates value counts for binning
sulfates_value_counts = red_wine_df['sulfates'].value_counts()
sulfates_value_counts
# Out:
# 0.60    69
# 0.58    68
# 0.54    68
# 0.62    61
# 0.56    60
#         ..
# 1.00     1
# 1.59     1
# 0.33     1
# 1.26     1
# 1.01     1
# Name: sulfates, Length: 96, dtype: int64

# %%
scaler = StandardScaler()

red_wine_df[['sulfates']] = scaler.fit_transform(red_wine_df[['sulfates']])

# %%
red_wine_df['sulfates'] = red_wine_df['sulfates'].round(decimals = 1)

# %%
red_wine_df.nunique()
# Out:
# type                     1
# fixed_acidity            7
# volatile_acidity         8
# citric_acid             10
# chlorides               12
# total_sulfur_dioxide     7
# density                  9
# sulfates                10
# alcohol                 65
# quality                  6
# dtype: int64

# %%
# Look at alcohol value counts for binning
alcohol_value_counts = red_wine_df['alcohol'].value_counts()
alcohol_value_counts
# Out:
# 9.500000     139
# 9.400000     103
# 9.800000      78
# 9.200000      72
# 10.000000     67
#             ...
# 9.950000       1
# 9.233333       1
# 9.250000       1
# 9.050000       1
# 10.750000      1
# Name: alcohol, Length: 65, dtype: int64

# %%
scaler = StandardScaler()

red_wine_df[['alcohol']] = scaler.fit_transform(red_wine_df[['alcohol']])

# %%
red_wine_df['alcohol'] = red_wine_df['alcohol'].round(decimals = 0)

# %%
red_wine_df.nunique()
# Out:
# type                     1
# fixed_acidity            7
# volatile_acidity         8
# citric_acid             10
# chlorides               12
# total_sulfur_dioxide     7
# density                  9
# sulfates                10
# alcohol                  7
# quality                  6
# dtype: int64

# %%
# Generate our categorical variable lists
red_wine_cat = red_wine_df.dtypes[red_wine_df.dtypes == "object"].index.tolist()

# %%
red_wine_df[red_wine_cat].nunique()
# Out:
# type    1
# dtype: int64
