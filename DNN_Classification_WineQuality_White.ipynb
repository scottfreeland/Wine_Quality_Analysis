# %%
# Import our dependencies
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler,OneHotEncoder
import pandas as pd
import tensorflow as tf

# %%
# Loading ipython-sql
# %load_ext sql

# %%
# Importing create_engine function from sqlalchemy
from sqlalchemy import create_engine

# %%
# Connecting ipython-sql to PostgreSQL Database
# %sql postgresql://postgres:pencil@localhost/wine_db

# %%
# Connecting sqlalchemy to PostgreSQL Database
engine = create_engine('postgresql://postgres:pencil@localhost/wine_db')

# %%
# Checking that we can pull data from PostgreSQL Database in cell below

# %%
# %%sql
#
# SELECT
#     *
# FROM white_wine_quality
# LIMIT 3
# Out:
#  * postgresql://postgres:***@localhost/wine_db
# 3 rows affected.
# [('white', '7', '0.27', '0.36', '20.7', '0.045', '45', '170', '1.001', '3', '0.45', '8.8', '6'),
#  ('white', '6.3', '0.3', '0.34', '1.6', '0.049', '14', '132', '0.994', '3.3', '0.49', '9.5', '6'),
#  ('white', '8.1', '0.28', '0.4', '6.9', '0.05', '30', '97', '0.9951', '3.26', '0.44', '10.1', '6')]

# %%
# Formulating DataFrame from Database
white_wine_df = pd.read_sql('SELECT * FROM white_wine_quality', engine)
white_wine_df
# Out:
#        type fixed_acidity volatile_acidity citric_acid residual_sugar  \
# 0     white             7             0.27        0.36           20.7
# 1     white           6.3              0.3        0.34            1.6
# 2     white           8.1             0.28         0.4            6.9
# 3     white           7.2             0.23        0.32            8.5
# 4     white           7.2             0.23        0.32            8.5
# ...     ...           ...              ...         ...            ...
# 4865  white           5.7             0.21        0.32            0.9
# 4866  white           6.2             0.21        0.29            1.6
# 4867  white           6.6             0.32        0.36              8
# 4868  white           5.5             0.29         0.3            1.1
# 4869  white             6             0.21        0.38            0.8
#
#      chlorides free_sulfur_dioxide total_sulfur_dioxide  density    ph  \
# 0        0.045                  45                  170    1.001     3
# 1        0.049                  14                  132    0.994   3.3
# 2         0.05                  30                   97   0.9951  3.26
# 3        0.058                  47                  186   0.9956  3.19
# 4        0.058                  47                  186   0.9956  3.19
# ...        ...                 ...                  ...      ...   ...
# 4865     0.038                  38                  121  0.99074  3.24
# 4866     0.039                  24                   92  0.99114  3.27
# 4867     0.047                  57                  168   0.9949  3.15
# 4868     0.022                  20                  110  0.98869  3.34
# 4869      0.02                  22                   98  0.98941  3.26
#
#      sulfates alcohol quality
# 0        0.45     8.8       6
# 1        0.49     9.5       6
# 2        0.44    10.1       6
# 3         0.4     9.9       6
# 4         0.4     9.9       6
# ...       ...     ...     ...
# 4865     0.46    10.6       6
# 4866      0.5    11.2       6
# 4867     0.46     9.6       5
# 4868     0.38    12.8       7
# 4869     0.32    11.8       6
#
# [4870 rows x 13 columns]

# %%
# Checking for any empty spaces in our data
white_wine_df.isnull().sum()
# Out:
# type                    0
# fixed_acidity           0
# volatile_acidity        0
# citric_acid             0
# residual_sugar          0
# chlorides               0
# free_sulfur_dioxide     0
# total_sulfur_dioxide    0
# density                 0
# ph                      0
# sulfates                0
# alcohol                 0
# quality                 0
# dtype: int64

# %%
white_wine_df.dtypes
# Out:
# type                    object
# fixed_acidity           object
# volatile_acidity        object
# citric_acid             object
# residual_sugar          object
# chlorides               object
# free_sulfur_dioxide     object
# total_sulfur_dioxide    object
# density                 object
# ph                      object
# sulfates                object
# alcohol                 object
# quality                 object
# dtype: object

# %%
white_wine_df = white_wine_df.astype({"fixed_acidity": float, "volatile_acidity": float, "citric_acid": float, "residual_sugar": float, "chlorides": float, "free_sulfur_dioxide": float, "total_sulfur_dioxide": float, "density": float, "ph": float, "sulfates": float, "alcohol": float, "quality": int})
white_wine_df.dtypes
# Out:
# type                     object
# fixed_acidity           float64
# volatile_acidity        float64
# citric_acid             float64
# residual_sugar          float64
# chlorides               float64
# free_sulfur_dioxide     float64
# total_sulfur_dioxide    float64
# density                 float64
# ph                      float64
# sulfates                float64
# alcohol                 float64
# quality                   int32
# dtype: object

# %%
# Drop the non-beneficial ID columns, 'residual_sugar', 'free_sulfur_dioxide', and 'ph'.
white_wine_df.drop(['residual_sugar', 'free_sulfur_dioxide', 'ph'], axis=1, inplace=True)

# %%
# Create Classification version of target variable
# Idea for classification inspired by Terence Shin on 
# towardsdatascience.com/predicting-wine-quality-with-several-classification-techniques-179038ea6434
white_wine_df['goodquality'] = [1 if x >= 7 else 0 for x in white_wine_df['quality']]

# %%
white_wine_df.head()
# Out:
#     type  fixed_acidity  volatile_acidity  citric_acid  chlorides  \
# 0  white            7.0              0.27         0.36      0.045
# 1  white            6.3              0.30         0.34      0.049
# 2  white            8.1              0.28         0.40      0.050
# 3  white            7.2              0.23         0.32      0.058
# 4  white            7.2              0.23         0.32      0.058
#
#    total_sulfur_dioxide  density  sulfates  alcohol  quality  goodquality
# 0                 170.0   1.0010      0.45      8.8        6            0
# 1                 132.0   0.9940      0.49      9.5        6            0
# 2                  97.0   0.9951      0.44     10.1        6            0
# 3                 186.0   0.9956      0.40      9.9        6            0
# 4                 186.0   0.9956      0.40      9.9        6            0

# %%
# Split our preprocessed data into our features and target arrays
y= white_wine_df["goodquality"].values
X = white_wine_df.drop(columns=["goodquality", 'type'], axis=1).values

# Split the preprocessed data into a training and testing dataset
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42)

# %%
# Create a StandardScaler instances
scaler = StandardScaler()

# Fit the StandardScaler
X_scaler = scaler.fit(X_train)

# Scale the data
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %%
# Define the model - deep neural net, i.e., the number of input features and hidden nodes for each layer.
number_input_features = len(X_train[0])
number_hidden_nodes_layer1 =  50
number_hidden_nodes_layer2 = 25

nn = tf.keras.models.Sequential()

# First hidden layer
nn.add(tf.keras.layers.Dense(units=number_hidden_nodes_layer1, activation="relu", input_dim=number_input_features))

# Second hidden layer
nn.add(tf.keras.layers.Dense(units=number_hidden_nodes_layer2, activation="relu", input_dim=number_input_features))

# Output layer
nn.add(tf.keras.layers.Dense(units=1, activation="sigmoid"))

# Check the structure of the model
nn.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 50)                500
#
#  dense_1 (Dense)             (None, 25)                1275
#
#  dense_2 (Dense)             (None, 1)                 26
#
# =================================================================
# Total params: 1,801
# Trainable params: 1,801
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Import checkpoint dependencies
import os
from tensorflow.keras.callbacks import ModelCheckpoint

# Define the checkpoint path and filenames
os.makedirs("checkpoints/",exist_ok=True)
checkpoint_path = "checkpoints/weights.{epoch:02d}.hdf5"

# %%
# Compile the model
nn.compile(loss="binary_crossentropy", optimizer="adam", metrics=["accuracy"])

# %%
# Create a callback that saves the model's weights every 5 epochs
cp_callback = ModelCheckpoint(
    filepath=checkpoint_path,
    verbose=1,
    save_weights_only=True,
    period=5)

# Train the model
fit_model = nn.fit(X_train_scaled,y_train,epochs=20,callbacks=[cp_callback])
# Out:
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of batches seen.
# Epoch 1/20
# 115/115 [==============================] - 2s 4ms/step - loss: 0.3692 - accuracy: 0.8817
# Epoch 2/20
# 115/115 [==============================] - 0s 4ms/step - loss: 0.0987 - accuracy: 0.9849
# Epoch 3/20
# 115/115 [==============================] - 0s 4ms/step - loss: 0.0222 - accuracy: 0.9986
# Epoch 4/20
# 115/115 [==============================] - 0s 4ms/step - loss: 0.0077 - accuracy: 0.9997
# Epoch 5/20
# 114/115 [============================>.] - ETA: 0s - loss: 0.0038 - accuracy: 1.0000
# Epoch 00005: saving model to checkpoints\weights.05.hdf5
# 115/115 [==============================] - 1s 5ms/step - loss: 0.0038 - accuracy: 1.0000
# Epoch 6/20
# 115/115 [==============================] - 0s 4ms/step - loss: 0.0022 - accuracy: 1.0000
# Epoch 7/20
# 115/115 [==============================] - 0s 4ms/step - loss: 0.0014 - accuracy: 1.0000
# Epoch 8/20
# 115/115 [==============================] - 0s 4ms/step - loss: 9.8906e-04 - accuracy: 1.0000
# Epoch 9/20
# 115/115 [==============================] - 0s 4ms/step - loss: 7.2551e-04 - accuracy: 1.0000
# Epoch 10/20
# 113/115 [============================>.] - ETA: 0s - loss: 5.5617e-04 - accuracy: 1.0000
# Epoch 00010: saving model to checkpoints\weights.10.hdf5
# 115/115 [==============================] - 1s 5ms/step - loss: 5.5587e-04 - accuracy: 1.0000
# Epoch 11/20
# 115/115 [==============================] - 0s 4ms/step - loss: 4.3714e-04 - accuracy: 1.0000
# Epoch 12/20
# 115/115 [==============================] - 0s 4ms/step - loss: 3.5226e-04 - accuracy: 1.0000
# Epoch 13/20
# 115/115 [==============================] - 0s 4ms/step - loss: 2.8803e-04 - accuracy: 1.0000: 0s - loss: 2.8421e-04 - accuracy: 1.00
# Epoch 14/20
# 115/115 [==============================] - 0s 4ms/step - loss: 2.3970e-04 - accuracy: 1.0000
# Epoch 15/20
# 109/115 [===========================>..] - ETA: 0s - loss: 2.0119e-04 - accuracy: 1.0000
# Epoch 00015: saving model to checkpoints\weights.15.hdf5
# 115/115 [==============================] - 1s 5ms/step - loss: 2.0093e-04 - accuracy: 1.0000
# Epoch 16/20
# 115/115 [==============================] - 0s 4ms/step - loss: 1.7174e-04 - accuracy: 1.0000
# Epoch 17/20
# 115/115 [==============================] - 0s 4ms/step - loss: 1.4709e-04 - accuracy: 1.0000
# Epoch 18/20
# 115/115 [==============================] - 1s 4ms/step - loss: 1.2704e-04 - accuracy: 1.0000
# Epoch 19/20
# 115/115 [==============================] - 0s 4ms/step - loss: 1.1082e-04 - accuracy: 1.0000
# Epoch 20/20
# 105/115 [==========================>...] - ETA: 0s - loss: 9.6738e-05 - accuracy: 1.0000
# Epoch 00020: saving model to checkpoints\weights.20.hdf5
# 115/115 [==============================] - 1s 5ms/step - loss: 9.7181e-05 - accuracy: 1.0000
